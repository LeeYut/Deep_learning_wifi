# %%
import pandas as pd
import numpy as np
import json
import urllib.request

# %%
df = pd.read_csv("wifidataset 3 201801131322.csv")
df.loc[25072:29356].to_csv("wifi_4th_floor_test.csv",index = False)
df = pd.read_csv("wifi_4th_floor.csv")

# %%
counter = 0
for index, row in df.iterrows():
    if(row['BBSID'] == "delimiter"):
        counter += 1

# %%
print (counter)
# Out:
# 40

# %%
wifi_list = []
time=[]
counter = 0
obj = {"wifiAccessPoints":[]}
for index, row in df.iterrows():
    if(row['BBSID'] == "delimiter"):
        counter += 1
        wifi_list.append(obj)
        obj = {"wifiAccessPoints":[]}
        time.append((counter, df.loc[index-1, ' Time']))
    else:
        obj["wifiAccessPoints"].append({"macAddress":row['BBSID'], "signalStrength":row[' Signal']})
print (wifi_list)
print (time)
# Out:
# [{'wifiAccessPoints': [{'signalStrength': '-63', 'macAddress': '48:a1:95:e9:0b:cb'}, {'signalStrength': '-76', 'macAddress': 'cc:e1:d5:8f:6e:76'}, {'signalStrength': '-71', 'macAddress': '00:1a:1e:83:c1:61'}, {'signalStrength': '-73', 'macAddress': '00:1a:1e:83:c1:62'}, {'signalStrength': '-72', 'macAddress': '00:1a:1e:83:c1:60'}, {'signalStrength': '-71', 'macAddress': 'cc:e1:d5:8f:6e:71'}, {'signalStrength': '-60', 'macAddress': '00:03:52:e3:7a:ac'}, {'signalStrength': '-62', 'macAddress': '00:03:52:e3:7a:ad'}, {'signalStrength': '-72', 'macAddress': '00:1a:1e:83:c1:63'}, {'signalStrength': '-79', 'macAddress': 'cc:e1:d5:f9:66:00'}, {'signalStrength': '-89', 'macAddress': '00:20:a6:cf:6f:b9'}, {'signalStrength': '-53', 'macAddress': '88:57:ee:f2:6a:48'}, {'signalStrength': '-68', 'macAddress': '10:6f:3f:37:5e:bb'}, {'signalStrength': '-60', 'macAddress': '00:03:52:e3:7a:ab'}, {'signalStrength': '-88', 'macAddress': 'bc:5c:4c:6c:56:2f'}, {'signalStrength': '-62', 'macAddress': '00:0
# ...

# %%
wifi_list = []
obj = {"wifiAccessPoints":[]}
for index, row in df.iterrows():
    if(row['BBSID'] == "delimiter"):
        counter += 1
        wifi_list.append(obj)
        obj = {"wifiAccessPoints":[]}
    else:
        obj["wifiAccessPoints"].append({"macAddress":row['BBSID'], "signalStrength":row[' Signal']})

for i in range(len(wifi_list)):
    objj = wifi_list[i]
    json_data = json.dumps(objj).encode("utf-8")
    Geolocation_key = "AIzaSyCIoVg2f41tb4FLDyBr0PFjkjwZ2gwIfQg"
    url = "https://www.googleapis.com/geolocation/v1/geolocate?key="+ Geolocation_key
    req = urllib.request.Request(url=url,data=json_data,headers={'Content-type':'application/json'})
    response = urllib.request.urlopen(req)
    content = json.loads(response.read().decode('utf-8'))
    lat = content['location']['lat']    
    Lng = content['location']['lng']    
    radius = content['accuracy']
    print (str(lat) + ','+str(Lng)+','+str(radius))
print (Lng)
print (radius)
# Out:
# 35.6806696,139.76373429999998,76.0
# 35.680631600000005,139.7637052,82.0
# 35.680631600000005,139.7637052,82.0
# 35.680642399999996,139.7635855,78.0
# 35.680642399999996,139.7635855,78.0
# 35.680642399999996,139.7635855,78.0
# 35.6806506,139.7635928,77.0
# 35.6806506,139.7635928,77.0
# 35.6806506,139.7635928,77.0
# 35.680666699999996,139.76365239999998,52.0
# 35.680666699999996,139.76365239999998,52.0
# 35.680666699999996,139.76365239999998,52.0
# 35.6806626,139.7634867,95.0
# 35.6806626,139.7634867,95.0
# 35.6806626,139.7634867,95.0
# 35.680665399999995,139.763445,101.0
# 35.680665399999995,139.763445,101.0
# 35.680665399999995,139.763445,101.0
# 35.680652099999996,139.7635566,94.0
# 35.680652099999996,139.7635566,94.0
# 35.680652099999996,139.7635566,94.0
# 35.6806677,139.763603,89.0
# 35.6806677,139.763603,89.0
# 35.6806677,139.763603,89.0
# 35.6806188,139.76371709999998,81.0
# 35.6806188,139.76371709999998,81.0
# 35.6806188,139.76371709999998,81.0
# 35.6806403,139.7637162,81.0
# ...

# %%
lat = 98
lon = 100
print (str(lat) + "," + str(lon))
# Out:
# 98,100

# %%
df= pd.read_csv("GPS dataset 4201711251339.csv") 
df_acc = pd.read_csv("Accel dataset 4201711251339.csv")

# %%
t_benchmark = df_acc["UPTIMENANO"][0]
print (t_benchmark)
# Out:
# 105277386671145

# %%
df['UPTIMENANO'] = (df['UPTIMENANO'] - t_benchmark)/1000000000
print (df)
# Out:
#       UPTIMENANO   Latitude   Longitude   speed   accuracy
# 0       0.610634  35.707489  139.760349    0.29       11.0
# 1       1.614549  35.707487  139.760351    0.47       11.0
# 2       2.616922  35.707476  139.760352    0.15       11.0
# 3       3.622625  35.707467  139.760351    0.26       11.0
# 4       4.624139  35.707454  139.760350    0.39       10.0
# 5       5.625687  35.707443  139.760351    0.56       10.0
# 6       6.625787  35.707428  139.760356    1.28       10.0
# 7       7.613833  35.707408  139.760360    1.46       10.0
# 8       8.628114  35.707400  139.760361    0.82       10.0
# 9       9.620121  35.707399  139.760360    0.30       10.0
# 10     10.621300  35.707395  139.760362    0.50       10.0
# 11     11.630719  35.707392  139.760362    0.27       10.0
# 12     12.630107  35.707392  139.760358    0.59       10.0
# 13     13.737864  35.707393  139.760354    0.42       10.0
# 14     15.637549  35.707401  139.760359    1.97       10.0
# ...

# %%
import datetime
df = pd.read_csv("wifi dataset 4201711251339.csv")
wifi_list = []
obj = {"wifiAccessPoints":[]}
time_list = []
time_benchmark = datetime.datetime.strptime(df.loc[0, ' Time'], '%d%H%M%S')
count = 0
for index, row in df.iterrows():
    if(row['BBSID'] == "delimiter"):
        wifi_list.append(obj)
        obj = {"wifiAccessPoints":[]}
        time = datetime.datetime.strptime(df.loc[index-1, ' Time'], '%d%H%M%S')
        time_list.append((time-time_benchmark).total_seconds())
    else:
        obj["wifiAccessPoints"].append({"macAddress":row['BBSID'], "signalStrength":row[' Signal']})
print (len(time_list))
print (len(wifi_list))
# Out:
# 206
# 206

# %%
def findTarget(time_second, time_list):
    for i in range(len(time_list)):
        if(time_list[i] > time_second):
            print (i, i-1)
            break
findTarget(118, time_list)
# Out:
# 11 10

# %%
objj = wifi_list[1]
json_data = json.dumps(objj).encode("utf-8")
Geolocation_key = "AIzaSyCIoVg2f41tb4FLDyBr0PFjkjwZ2gwIfQg"
url = "https://www.googleapis.com/geolocation/v1/geolocate?key="+ Geolocation_key
req = urllib.request.Request(url=url,data=json_data,headers={'Content-type':'application/json'})
response = urllib.request.urlopen(req)
content = json.loads(response.read().decode('utf-8'))
lat = content['location']['lat']    
Lng = content['location']['lng']    
radius = content['accuracy']
print (lat)
print (Lng)












WIFI-3-FLOOR
